# %% [markdown]
# ## Data Augmentation

# %%
import tensorflow
from tensorflow import keras
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt

# %% [markdown]
# ### On Single Image

# %%
img = image.load_img('../datasets/cat.avif', target_size=(675, 675))

# %%
plt.imshow(img)

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
data_generator = ImageDataGenerator(
    rotation_range = 30,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    brightness_range = (0.8, 1.2),
    zoom_range = 0.2,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = False,
    fill_mode='nearest'
)

# %%
img = image.img_to_array(img)

# %%
img.shape
# Out:
# (675, 675, 3)

# %%
input_batch = img.reshape(1, 675, 675, 3)

# %%
i = 0
for _ in data_generator.flow(input_batch, batch_size=1, save_to_dir='aug_images'):

    i+=1
    if i == 20:
        break

# %% [markdown]
# ### Augmentation through a directroy

# %%
generator = data_generator.flow_from_directory(
    'aug_images/',
    batch_size=20,
    target_size=(675, 675),
    save_prefix='cat', 
    save_format='png',
    save_to_dir='aug_images_cat/'
)
